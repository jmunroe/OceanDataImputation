# %%
import pandas as pd
import os
import csv
import io
import numpy as np
import matplotlib.pyplot as plt

# %%
metadata = pd.read_csv('metadata.csv')
metadata
# Out:
#       Unnamed: 0        waterbody                   station   latitude  \
# 0              0  Annapolis Basin                      1042  44.652855
# 1              1  Annapolis Basin                      5005  44.634167
# 2              2  Annapolis Basin                      5006  44.669583
# 3              3  Annapolis Basin                Cornwallis  44.669390
# 4              4  Annapolis Basin                Cornwallis  44.669390
# ...          ...              ...                       ...        ...
# 1693        1693  Bras d'Or Lakes          Little Narrows S  45.986409
# 1694        1694  Bras d'Or Lakes              Nyanza Bay E  46.065243
# 1695        1695  Bras d'Or Lakes              Nyanza Bay W  46.064779
# 1696        1696  Bras d'Or Lakes  Little Bras d'Or Channel  46.296261
# 1697        1697  Bras d'Or Lakes     St. Andrews Channel E  46.243290
#
#       longitude            deployment_range  sensor_type  \
# ...

# %%
waterbodies = metadata['waterbody'].unique()
waterbodies
# Out:
# array(['Annapolis Basin', 'Beaver Harbour', 'Halifax Harbour',
#        'Lawrencetown Beach', 'Owls Head Bay', 'Shad Bay', 'Sheet Harbour',
#        'Shoal Bay', 'Sober Island Pond', 'Spry Bay', 'St. Margarets Bay',
#        'Aspotogan Harbour', 'Mahone Bay', 'Chedabucto Bay',
#        'Country Harbour', 'Dover Bay', 'Fishermans Harbour',
#        'Indian Harbour', 'Marie Joseph Harbour', 'New Harbour',
#        'Strait of Canso', 'Tor Bay', 'Whitehead Harbour', 'Wine Harbour',
#        'McNabs Bay', 'Tatamagouche Bay', 'Caribou Harbour',
#        'Chance Harbour', 'French Channel', 'Little Harbour',
#        'Merigomish Harbour', 'Green Harbour', 'Negro Harbour',
#        'Port La Tour', 'Shelburne Harbour', 'Woods Harbour',
#        "Bras d'Or Lakes", 'Denas Pond', 'Mabou Harbour',
#        'Whycocomagh Basin', 'Whycocomagh Bay', 'Antigonish Harbour',
#        'Grahams Cove', 'Havre Boucher', 'Monks Head Harbour',
#        'St. Georges Bay', 'Tracadie Harbour', 'Careys Cove',
# ...
