# %% [markdown]
# # Split data in to separate segements

# %%
import os
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# We now have the following `.csv` files stored locally

# %%
# !ls -lh data/
# Out:
# total 2.0G
# -rw-r--r-- 1 jmunroe jmunroe  40M May 22 21:24 Annapolis.csv
# -rw-r--r-- 1 jmunroe jmunroe 106M May 22 21:25 Antigonish.csv
# -rw-r--r-- 1 jmunroe jmunroe  33M May 22 21:25 Colchester.csv
# -rw-r--r-- 1 jmunroe jmunroe 127M May 22 21:26 Digby.csv
# -rw-r--r-- 1 jmunroe jmunroe 774M May 22 21:27 Guysborough.csv
# -rw-r--r-- 1 jmunroe jmunroe 163M May 22 21:28 Halifax.csv
# -rw-r--r-- 1 jmunroe jmunroe  30M May 22 21:28 Inverness.csv
# -rw-r--r-- 1 jmunroe jmunroe 236M May 22 21:30 Lunenburg.csv
# -rw-r--r-- 1 jmunroe jmunroe  41M May 22 21:30 Pictou.csv
# -rw-r--r-- 1 jmunroe jmunroe  89M May 22 21:31 Queens.csv
# -rw-r--r-- 1 jmunroe jmunroe  95M May 22 21:31 Richmond.csv
# -rw-r--r-- 1 jmunroe jmunroe  96M May 22 21:32 Shelburne.csv
# -rw-r--r-- 1 jmunroe jmunroe 241K May 22 21:32 Victoria.csv
# -rw-r--r-- 1 jmunroe jmunroe 219M May 22 21:33 Yarmouth.csv

# %% [markdown]
# We need to organize and sort the observations so that we are considering only the observation for a single sensor in temporal order.
#
# This will remove all of the duplicated metadata within this `.csv` files.

# %%
os.makedirs('segments', exist_ok=True)

all_segment_metadata = []
for index, row in tqdm(list(df_CMAR_datasets.iterrows())):

    csvfile = f"data/{row['county']}.csv"

    df = pd.read_csv(csvfile)

    df.drop(columns=['Unnamed: 0'], inplace=True)
    
    df['segment'] = df[['waterbody', 'station', 
                        #'sensor_serial_number', 'latitude (degrees_north)', 'longitude (degrees_east)',
                     'deployment_start_date (UTC)', 'deployment_end_date (UTC)',
                     'depth (m)']].agg(lambda x: row['county'] + '_' + '_'.join([str(y) for y in x]), axis=1)

    df_metadata = df[['segment', 'waterbody', 'station', 
                      # 'sensor_serial_number',  'latitude (degrees_north)', 'longitude (degrees_east)',
                     'deployment_start_date (UTC)', 'deployment_end_date (UTC)',
                     'depth (m)']]

    df_metadata = df_metadata.drop_duplicates()
    all_segment_metadata.append(df_metadata)
    
    df_data = df.drop(columns=['waterbody', 'station', 
                               #'sensor_serial_number',                     'latitude (degrees_north)', 'longitude (degrees_east)',
                     'deployment_start_date (UTC)', 'deployment_end_date (UTC)',
                     'depth (m)'])
    
    df_data = df_data.sort_values(by=['segment', 'time (UTC)'])

    df_data.set_index(['segment', 'time (UTC)'], inplace=True)

    for key, segment_df in df_data.groupby(level=0):
        csvfile = f'segments/{key}.csv'
        segment_df = segment_df.droplevel(0)
        segment_df.to_csv(csvfile)

df_metadata = pd.concat(all_segment_metadata)
df_metadata.set_index('segment', inplace=True)
df_metadata.to_csv('metadata.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 os.makedirs('segments', exist_ok=True)
#       3 all_segment_metadata = []
# ----> 4 for index, row in tqdm(list(df_CMAR_datasets.iterrows())):
#       6     csvfile = f"data/{row['county']}.csv"
#       8     df = pd.read_csv(csvfile)
#
# NameError: name 'df_CMAR_datasets' is not defined

# %%
# !ls -lh segments/ | wc
# Out:
#     805    9197  131954

# %% [markdown]
# We have ~800 distinct observational time series taken at various locations and depths around Nova Scotia during the period of 2020-09-01 to 2024-08-31

# %%
df_metadata
# Out:
#                                                            waterbody  \
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...   Annapolis Basin
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...   Annapolis Basin
# Annapolis_Annapolis Basin_Cornwallis_670367_44....   Annapolis Basin
# Annapolis_Annapolis Basin_Cornwallis_670380_44....   Annapolis Basin
# Annapolis_Annapolis Basin_Cornwallis_547089_44....   Annapolis Basin
# ...                                                              ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...       Lobster Bay
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...      Lamonts Cove
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...       Careys Cove
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...       Lobster Bay
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...  Chebogue Harbour
#
#                                                            station  \
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...   Lobster Ledge
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...   Lobster Ledge
# Annapolis_Annapolis Basin_Cornwallis_670367_44....      Cornwallis
# Annapolis_Annapolis Basin_Cornwallis_670380_44....      Cornwallis
# Annapolis_Annapolis Basin_Cornwallis_547089_44....      Cornwallis
# ...                                                            ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...     Lobster Bay
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...     Short Beach
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...    Yarmouth Bar
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...      Ram Island
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...  Big Pond Point
#
#                                                     sensor_serial_number  \
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...              20820380
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...                670381
# Annapolis_Annapolis Basin_Cornwallis_670367_44....                670367
# Annapolis_Annapolis Basin_Cornwallis_670380_44....                670380
# Annapolis_Annapolis Basin_Cornwallis_547089_44....                547089
# ...                                                                  ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...                548559
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...                548563
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...                548586
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...                548597
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...                549342
#
#                                                     latitude (degrees_north)  \
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...                 44.678200
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...                 44.678200
# Annapolis_Annapolis Basin_Cornwallis_670367_44....                 44.669390
# Annapolis_Annapolis Basin_Cornwallis_670380_44....                 44.669420
# Annapolis_Annapolis Basin_Cornwallis_547089_44....                 44.669420
# ...                                                                      ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...                 43.679035
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...                 43.930927
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...                 43.831528
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...                 43.682230
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...                 43.770430
#
#                                                     longitude (degrees_east)  \
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...                -65.683290
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...                -65.683290
# Annapolis_Annapolis Basin_Cornwallis_670367_44....                -65.644790
# Annapolis_Annapolis Basin_Cornwallis_670380_44....                -65.644770
# Annapolis_Annapolis Basin_Cornwallis_547089_44....                -65.644770
# ...                                                                      ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...                -65.897960
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...                -66.167984
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...                -66.173210
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...                -65.836205
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...                -66.135150
#
#                                                    deployment_start_date (UTC)  \
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...        2020-06-11T00:00:00Z
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...        2020-06-11T00:00:00Z
# Annapolis_Annapolis Basin_Cornwallis_670367_44....        2020-06-11T00:00:00Z
# Annapolis_Annapolis Basin_Cornwallis_670380_44....        2020-11-22T00:00:00Z
# Annapolis_Annapolis Basin_Cornwallis_547089_44....        2020-11-22T00:00:00Z
# ...                                                                        ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...        2023-08-02T00:00:00Z
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...        2023-08-03T00:00:00Z
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...        2023-08-03T00:00:00Z
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...        2023-08-02T00:00:00Z
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...        2023-08-03T00:00:00Z
#
#                                                    deployment_end_date (UTC)  \
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...      2020-11-22T00:00:00Z
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...      2020-11-22T00:00:00Z
# Annapolis_Annapolis Basin_Cornwallis_670367_44....      2020-11-22T00:00:00Z
# Annapolis_Annapolis Basin_Cornwallis_670380_44....      2021-06-16T00:00:00Z
# Annapolis_Annapolis Basin_Cornwallis_547089_44....      2021-06-16T00:00:00Z
# ...                                                                      ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...      2024-08-07T00:00:00Z
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...      2024-08-07T00:00:00Z
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...      2024-08-07T00:00:00Z
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...      2024-08-07T00:00:00Z
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...      2024-08-07T00:00:00Z
#
#                                                     depth (m)
# segment
# Annapolis_Annapolis Basin_Lobster Ledge_2082038...        2.0
# Annapolis_Annapolis Basin_Lobster Ledge_670381_...        4.0
# Annapolis_Annapolis Basin_Cornwallis_670367_44....        1.0
# Annapolis_Annapolis Basin_Cornwallis_670380_44....        1.0
# Annapolis_Annapolis Basin_Cornwallis_547089_44....        2.0
# ...                                                       ...
# Yarmouth_Lobster Bay_Lobster Bay_548559_43.6790...        5.0
# Yarmouth_Lamonts Cove_Short Beach_548563_43.930...       15.0
# Yarmouth_Careys Cove_Yarmouth Bar_548586_43.831...       15.0
# Yarmouth_Lobster Bay_Ram Island_548597_43.68223...        8.0
# Yarmouth_Chebogue Harbour_Big Pond Point_549342...       12.0
#
# [804 rows x 8 columns]
